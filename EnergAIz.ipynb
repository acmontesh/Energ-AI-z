# %% [markdown]
# # Energy AI Hackathon 2026
# The University of Texas at Austin

# %% [markdown]
# ### Energ-AI-z Team
# <ul>
# <li>Simon Montoya</li>
# <li>Dalma Cerro</li>
# <li>Joao Brandao</li>
# <li>Chris Lopez</li>
# <li>Abraham C. Montes</li>
# </ul>

# %% [markdown]
# This notebook contains the solution to the 2026 PGE Hackathon Problem proposed by the team Energ-AI-z

# %% [markdown]
# ## Libraries, Imports, and Separate Python Files

# %%
import pandas as pd #Handling tabular data
import numpy as np #Handling arrays
import matplotlib.pyplot as plt #Plots

# %% [markdown]
# ## Feature Exploration

# %% [markdown]
# ## Feature Imputation

# %% [markdown]
# ## Feature Transformation, Selection and Engineering

# %% [markdown]
# ## Predictive Model Building

# %% [markdown]
# ## Accuracy Measurement

# %% [markdown]
# ## Uncertainty Model Construction

# %% [markdown]
# ## Predictions for the Hackathon Test Dataset
